# %%
'''

测试算法：K邻近算法

测试数据集：dred数据集
----------------
    描述：选取电视、冰箱、电脑和加热器四种电器
    时长：2015-09-01 11：30至2015-09-01 14:00，共150分钟
    数量：压缩前36004个数据，压缩后7200个数据
    
测试结果：准确率97.64%

'''

# %%
#check path
import sys
if '..' not in sys.path:
    sys.path.append('..')

# %%
#import tools
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from disaggregate.data_extender import extend_and_combine
from disaggregate.pca_and_knn import *
# %matplotlib inline

# %%
#define a plot function
color_list = ['r', 'y', 'g', 'c', 'b', 'm', 'k', 'w']
def plot(*raws):
    plt.figure(figsize = [20, 20])
    for index, raw in enumerate(raws):
        plt.plot(raw.index, raw.values, color_list[index])
    plt.show()

# %%
#import data
with pd.HDFStore('../dataset_test/DRED.h5') as f:
    tv = f.get('/building1/elec/meter2')['power']['apparent']['2015-09-01 11:30:00+05:30':'2015-09-01 14:00:00+05:30']
    fg = f.get('/building1/elec/meter4')['power']['apparent']['2015-09-01 11:30:00+05:30':'2015-09-01 14:00:00+05:30']
    cp = f.get('/building1/elec/meter5')['power']['apparent']['2015-09-01 11:30:00+05:30':'2015-09-01 14:00:00+05:30']
    hp = f.get('./building1/elec/meter6')['power']['apparent']['2015-09-01 11:30:00+05:30':'2015-09-01 14:00:00+05:30']

# %%
#plot data
plot(tv, fg, cp, hp)
# Out:
# /home/redbeancakeli/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#entend and combine dataset
dataset, labels = extend_and_combine(5, tv.values, fg.values, cp.values, hp.values)
# Out:
# extending dataset 0  size: (9001,)
#
# combining dataset 0  size: (1800, 8)
#
# extending dataset 1  size: (9001,)
#
# combining dataset 1  size: (1800, 8)
#
# extending dataset 2  size: (9001,)
#
# combining dataset 2  size: (1800, 8)
#
# extending dataset 3  size: (9001,)
#
# combining dataset 3  size: (1800, 8)
#
# done!

# %%
#split dataset
x_train,x_test,y_train,y_test = train_test_split(dataset, labels, test_size = 0.3)

# %%
#train dataset
model = train(x_train, y_train, 4)
# Out:
# Trained: displaying 100 % data...
# True: displaying 100 % data...

# %%
#predict
pred = predict_all(x_test, y_test, 4, model)
# Out:
# Predict: displaying 100 % data...
# True: displaying 100 % data...

# %%
#confusion matrix
cm = confusion_matrix(y_test, pred)
plt.matshow(cm)
plt.colorbar()
plt.xlabel('predict')
plt.ylabel('true')
plt.show()
print(cm)
# Out:
# [[525   0   0   2]
#  [  0 537   3  11]
#  [  0   0 548   0]
#  [  8  17  10 499]]

# %%
#accuracy
acc = sum(cm.diagonal())/sum(sum(cm))
print('accuracy: ', acc*100, '%')
# Out:
# accuracy:  97.63888888888889 %
